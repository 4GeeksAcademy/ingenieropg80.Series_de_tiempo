# %%
# Out:
# === ANÁLISIS DE ESTACIONARIEDAD ===
#
# Serie Original:
# ADF Statistic: 0.545414
# p-value: 0.986190
# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571
# ✗ Serie NO es estacionaria (no rechazamos H0)
#
# === APLICANDO DIFERENCIACIÓN ===
#
# Serie Diferenciada (d=1):
# ADF Statistic: -9.430263
# p-value: 0.000000
# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571
# ✓ Serie es estacionaria (rechazamos H0)
#
# === ANÁLISIS ACF/PACF ===
# === DIVISIÓN DE DATOS ===
# Entrenamiento: 336 observaciones (2022-09-03 a 2023-08-04)
# Prueba: 30 observaciones (2023-08-05 a 2023-09-03)
#
# === BÚSQUEDA DE PARÁMETROS ARIMA ===
# Evaluando combinaciones de parámetros...
# ARIMA(0, 0, 0): AIC=4673.80, MAE=475.864, RMSE=476.419
# ARIMA(0, 0, 1): AIC=4232.86, MAE=467.100, RMSE=470.817
# ARIMA(0, 0, 2): AIC=3838.06, MAE=462.652, RMSE=467.714
# ARIMA(0, 0, 3): AIC=3646.84, MAE=449.486, RMSE=460.850
# ARIMA(0, 1, 0): AIC=2035.04, MAE=38.385, RMSE=44.486
# ...
